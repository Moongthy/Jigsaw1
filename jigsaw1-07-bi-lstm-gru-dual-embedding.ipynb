# %% [markdown]
# # 0. Import libraries

# %%
import numpy as np
import pandas as pd
import os
from keras.models import Model
from keras.layers import Input, Dense, Embedding, SpatialDropout1D, add, concatenate
from keras.layers import CuDNNLSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D, CuDNNGRU, Conv1D
from keras.preprocessing import text, sequence
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
print(tf.__version__)
tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)
# Out:
# 2.8.2
# WARNING:tensorflow:From <ipython-input-2-c0765aaa717d>:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # 1. Load data

# %%
BASE_DIR = '/content/drive/MyDrive/NLP/ENG/Jigsaw1/'
WV_DIR = '/content/drive/MyDrive/NLP/ENG/wordvector/'
MODEL_DIR = BASE_DIR + 'model/'
DATA_DIR = BASE_DIR + 'input/'
OUTPUT_DIR = BASE_DIR + 'output/'

EMBEDDING_FILES = [
                   WV_DIR + 'fasttext/crawl-300d-2M.vec',
                   WV_DIR + 'glove/glove.840B.300d.txt']
TEXT_COLUMN = 'comment_text'
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
CHARS_TO_REMOVE = '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n“”’\'∞θ÷α•à−β∅³π‘₹´°£€\×™√²—'

# %%
train_df = pd.read_csv(DATA_DIR + 'train.csv')
test_df = pd.read_csv(DATA_DIR + 'test.csv')
submission = pd.read_csv(DATA_DIR + 'sample_submission.csv')

# %%
y = train_df[list_classes].values
x_train = train_df[TEXT_COLUMN].astype(str)
y_train = y
x_test = test_df[TEXT_COLUMN].astype(str)

# %% [markdown]
# # 2. Embedding

# %%
def get_coefs(word, *arr):
    return word, np.asarray(arr, dtype='float32')

# %%
def load_embedding(path):
  with open(path) as f:
    return dict(get_coefs(*line.strip().split(' ')) for line in f)

# %%
def build_matrix(word_index, path):
  embedding_index = load_embedding(path)
  embedding_matrix = np.zeros((len(word_index)+1, 300))
  for word, i in word_index.items():
    try: 
      embedding_matrix[i] = embedding_index[word]
    except KeyError:
      pass
  return embedding_matrix

# %%
# %%time
tokenizer = text.Tokenizer(filters=CHARS_TO_REMOVE)
tokenizer.fit_on_texts(list(x_train) + list(x_test))

MAX_LEN = 220

x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)
x_train = sequence.pad_sequences(x_train, maxlen=MAX_LEN)
x_test = sequence.pad_sequences(x_test, maxlen=MAX_LEN)
# Out:
# CPU times: user 37.5 s, sys: 469 ms, total: 38 s
# Wall time: 37.7 s

# %%
# %%time
embedding_matrix = np.concatenate(
    [build_matrix(tokenizer.word_index, f) for f in EMBEDDING_FILES], axis=1
)
# Out:
# CPU times: user 3min 22s, sys: 20.6 s, total: 3min 42s
# Wall time: 3min 41s

# %%
embedding_matrix.shape
# Out:
# (358905, 600)

# %% [markdown]
# # 3. Modeling

# %%
BATCH_SIZE = 512
LSTM_UNITS = 128
DENSE_HIDDEN_UNITS = 4 * LSTM_UNITS
EPOCHS = 4

def build_model(embedding_matrix):
  words = Input(shape=(None, ))
  x = Embedding(*embedding_matrix.shape, weights=[embedding_matrix], trainable=False)(words)
  # x = SpatialDropout1D(.2)(x)

  x1 = SpatialDropout1D(.2)(x)

  x = Bidirectional(CuDNNGRU(LSTM_UNITS, return_sequences = True))(x1)
  x = Conv1D(64, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(x)
  
  y = Bidirectional(CuDNNLSTM(LSTM_UNITS, return_sequences = True))(x1)
  y = Conv1D(64, kernel_size = 2, padding = "valid", kernel_initializer = "he_uniform")(y)

  avg_pool1 = GlobalAveragePooling1D()(x)
  max_pool1 = GlobalMaxPooling1D()(x)
  
  avg_pool2 = GlobalAveragePooling1D()(y)
  max_pool2 = GlobalMaxPooling1D()(y)

  x = concatenate([avg_pool1, max_pool1, avg_pool2, max_pool2])

  x = Dense(6, activation='sigmoid')(x)

  model = Model(inputs=words, outputs=x)

  # model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  return model

# %%
X_train, X_valid, Y_train ,Y_valid = train_test_split(x_train, y_train, test_size=.1)

# %%
EPOCHS = 5
SEEDS = 10

pred = 0

for ii in range(SEEDS):
  model = build_model(embedding_matrix)
  for global_epoch in range(EPOCHS):
    print(global_epoch)
    model.fit(
        X_train,
        Y_train,
        validation_data=(X_valid, Y_valid),
        batch_size=128,
        epochs=1,
        verbose=2,
        callbacks=[
                   LearningRateScheduler(lambda _: 1e-3*(0.55 ** global_epoch))
        ]
    )
    val_preds_3 = model.predict(X_valid)
    AUC = 0
    for i in range(6):
      AUC += roc_auc_score(Y_valid[:, i], val_preds_3[:, i])/6.
    print(AUC)
  pred += model.predict(x_test, batch_size=1024, verbose=1)/SEEDS
  model.save_weights(MODEL_DIR + 'bilstm_gru_dual_embedding_' + str(ii) + '.h5')
  os.system('gzip' + 'model_weights_' + str(ii) + '.h5')
# Out:
# 0
# 1122/1122 - 151s - loss: 0.0514 - accuracy: 0.9339 - val_loss: 0.0404 - val_accuracy: 0.9761 - lr: 0.0010 - 151s/epoch - 134ms/step
# 0.9900521542599259
# 1
# 1122/1122 - 133s - loss: 0.0387 - accuracy: 0.9756 - val_loss: 0.0381 - val_accuracy: 0.9898 - lr: 5.5000e-04 - 133s/epoch - 118ms/step
# 0.9908076803704849
# 2
# 1122/1122 - 134s - loss: 0.0354 - accuracy: 0.9729 - val_loss: 0.0373 - val_accuracy: 0.9620 - lr: 3.0250e-04 - 134s/epoch - 119ms/step
# 0.9909609647791054
# 3
# 1122/1122 - 134s - loss: 0.0331 - accuracy: 0.9687 - val_loss: 0.0367 - val_accuracy: 0.9647 - lr: 1.6638e-04 - 134s/epoch - 120ms/step
# 0.9911299548682785
# 4
# 1122/1122 - 133s - loss: 0.0314 - accuracy: 0.9677 - val_loss: 0.0369 - val_accuracy: 0.9641 - lr: 9.1506e-05 - 133s/epoch - 119ms/step
# 0.9912073187179473
# 150/150 [==============================] - 43s 269ms/step
# 0
# 1122/1122 - 137s - loss: 0.0513 - accuracy: 0.9045 - val_loss: 0.0401 - val_accuracy: 0.9874 - lr: 0.0010 - 137s/epoch - 122ms/step
# 0.989048021050676
# 1
# 1122/1122 - 133s - loss: 0.0389 - accuracy: 0.9459 - val_loss: 0.0380 - val_accuracy: 0.9761 - lr: 5.5000e-04 - 133s/epoch - 119ms/step
# 0.9905710597327297
# 2
# 1122/1122 - 134s - loss: 0.0355 - accuracy: 0.9549 - val_loss: 0.0373 - val_accuracy: 0.9673 - lr: 3.0250e-04 - 134s/epoch - 120ms/step
# 0.9909498034503932
# 3
# 1122/1122 - 134s - loss: 0.0333 - accuracy: 0.9535 - val_loss: 0.0371 - val_accuracy: 0.9430 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9910770250685462
# 4
# 1122/1122 - 134s - loss: 0.0317 - accuracy: 0.9499 - val_loss: 0.0368 - val_accuracy: 0.9410 - lr: 9.1506e-05 - 134s/epoch - 119ms/step
# 0.9911054312020412
# 150/150 [==============================] - 39s 260ms/step
# 0
# 1122/1122 - 136s - loss: 0.0504 - accuracy: 0.9030 - val_loss: 0.0394 - val_accuracy: 0.8673 - lr: 0.0010 - 136s/epoch - 121ms/step
# 0.9900456394160402
# 1
# 1122/1122 - 134s - loss: 0.0385 - accuracy: 0.9405 - val_loss: 0.0375 - val_accuracy: 0.9761 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9905930351729859
# 2
# 1122/1122 - 133s - loss: 0.0349 - accuracy: 0.9543 - val_loss: 0.0376 - val_accuracy: 0.9735 - lr: 3.0250e-04 - 133s/epoch - 119ms/step
# 0.9911052997808876
# 3
# 1122/1122 - 134s - loss: 0.0324 - accuracy: 0.9348 - val_loss: 0.0373 - val_accuracy: 0.9714 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9910346218448507
# 4
# 1122/1122 - 133s - loss: 0.0306 - accuracy: 0.9331 - val_loss: 0.0370 - val_accuracy: 0.8945 - lr: 9.1506e-05 - 133s/epoch - 119ms/step
# 0.9910552319059935
# 150/150 [==============================] - 39s 259ms/step
# 0
# 1122/1122 - 136s - loss: 0.0512 - accuracy: 0.9253 - val_loss: 0.0400 - val_accuracy: 0.9736 - lr: 0.0010 - 136s/epoch - 121ms/step
# 0.9892804854838958
# 1
# 1122/1122 - 135s - loss: 0.0390 - accuracy: 0.9645 - val_loss: 0.0388 - val_accuracy: 0.9643 - lr: 5.5000e-04 - 135s/epoch - 120ms/step
# 0.990528600125129
# 2
# 1122/1122 - 133s - loss: 0.0355 - accuracy: 0.9693 - val_loss: 0.0372 - val_accuracy: 0.9464 - lr: 3.0250e-04 - 133s/epoch - 119ms/step
# 0.9907426045941683
# 3
# 1122/1122 - 132s - loss: 0.0333 - accuracy: 0.9698 - val_loss: 0.0371 - val_accuracy: 0.9813 - lr: 1.6638e-04 - 132s/epoch - 118ms/step
# 0.9908971276552161
# 4
# 1122/1122 - 133s - loss: 0.0317 - accuracy: 0.9702 - val_loss: 0.0372 - val_accuracy: 0.9650 - lr: 9.1506e-05 - 133s/epoch - 118ms/step
# 0.9908960595613234
# 150/150 [==============================] - 39s 258ms/step
# 0
# 1122/1122 - 137s - loss: 0.0499 - accuracy: 0.9190 - val_loss: 0.0399 - val_accuracy: 0.9351 - lr: 0.0010 - 137s/epoch - 122ms/step
# 0.9900669849597833
# 1
# 1122/1122 - 134s - loss: 0.0387 - accuracy: 0.9463 - val_loss: 0.0391 - val_accuracy: 0.9832 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9906332288197405
# 2
# 1122/1122 - 134s - loss: 0.0350 - accuracy: 0.9578 - val_loss: 0.0381 - val_accuracy: 0.8593 - lr: 3.0250e-04 - 134s/epoch - 119ms/step
# 0.9909604369392447
# 3
# 1122/1122 - 134s - loss: 0.0326 - accuracy: 0.9563 - val_loss: 0.0375 - val_accuracy: 0.9749 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9909890688646643
# 4
# 1122/1122 - 133s - loss: 0.0309 - accuracy: 0.9500 - val_loss: 0.0373 - val_accuracy: 0.9534 - lr: 9.1506e-05 - 133s/epoch - 118ms/step
# 0.9909700896416811
# 150/150 [==============================] - 39s 260ms/step
# 0
# 1122/1122 - 136s - loss: 0.0504 - accuracy: 0.9145 - val_loss: 0.0422 - val_accuracy: 0.9259 - lr: 0.0010 - 136s/epoch - 122ms/step
# 0.9896313739551601
# 1
# 1122/1122 - 134s - loss: 0.0384 - accuracy: 0.9635 - val_loss: 0.0373 - val_accuracy: 0.9680 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9910434938693187
# 2
# 1122/1122 - 134s - loss: 0.0351 - accuracy: 0.9600 - val_loss: 0.0368 - val_accuracy: 0.9100 - lr: 3.0250e-04 - 134s/epoch - 119ms/step
# 0.9911997877562657
# 3
# 1122/1122 - 134s - loss: 0.0325 - accuracy: 0.9546 - val_loss: 0.0372 - val_accuracy: 0.8688 - lr: 1.6638e-04 - 134s/epoch - 120ms/step
# 0.9911652176351962
# 4
# 1122/1122 - 134s - loss: 0.0309 - accuracy: 0.9538 - val_loss: 0.0369 - val_accuracy: 0.9642 - lr: 9.1506e-05 - 134s/epoch - 119ms/step
# 0.9911428494075194
# 150/150 [==============================] - 39s 261ms/step
# 0
# 1122/1122 - 137s - loss: 0.0497 - accuracy: 0.9029 - val_loss: 0.0398 - val_accuracy: 0.9843 - lr: 0.0010 - 137s/epoch - 122ms/step
# 0.9893333715162911
# 1
# 1122/1122 - 134s - loss: 0.0385 - accuracy: 0.9527 - val_loss: 0.0376 - val_accuracy: 0.9459 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9901532928209353
# 2
# 1122/1122 - 133s - loss: 0.0350 - accuracy: 0.9562 - val_loss: 0.0376 - val_accuracy: 0.9765 - lr: 3.0250e-04 - 133s/epoch - 118ms/step
# 0.9905030099087617
# 3
# 1122/1122 - 134s - loss: 0.0326 - accuracy: 0.9533 - val_loss: 0.0372 - val_accuracy: 0.9470 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9907522811362788
# 4
# 1122/1122 - 134s - loss: 0.0310 - accuracy: 0.9360 - val_loss: 0.0369 - val_accuracy: 0.9553 - lr: 9.1506e-05 - 134s/epoch - 119ms/step
# 0.9907980912086058
# 150/150 [==============================] - 39s 261ms/step
# 0
# 1122/1122 - 138s - loss: 0.0502 - accuracy: 0.9057 - val_loss: 0.0399 - val_accuracy: 0.9687 - lr: 0.0010 - 138s/epoch - 123ms/step
# 0.9896446089607085
# 1
# 1122/1122 - 134s - loss: 0.0385 - accuracy: 0.9554 - val_loss: 0.0374 - val_accuracy: 0.9857 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9907715336576108
# 2
# 1122/1122 - 134s - loss: 0.0352 - accuracy: 0.9637 - val_loss: 0.0369 - val_accuracy: 0.9556 - lr: 3.0250e-04 - 134s/epoch - 119ms/step
# 0.9911813553435409
# 3
# 1122/1122 - 133s - loss: 0.0326 - accuracy: 0.9536 - val_loss: 0.0367 - val_accuracy: 0.9538 - lr: 1.6638e-04 - 133s/epoch - 119ms/step
# 0.9911291904416042
# 4
# 1122/1122 - 134s - loss: 0.0310 - accuracy: 0.9429 - val_loss: 0.0366 - val_accuracy: 0.9505 - lr: 9.1506e-05 - 134s/epoch - 119ms/step
# 0.99119569147001
# 150/150 [==============================] - 38s 258ms/step
# 0
# 1122/1122 - 137s - loss: 0.0497 - accuracy: 0.9098 - val_loss: 0.0400 - val_accuracy: 0.9734 - lr: 0.0010 - 137s/epoch - 122ms/step
# 0.9895177726244802
# 1
# 1122/1122 - 134s - loss: 0.0385 - accuracy: 0.9613 - val_loss: 0.0376 - val_accuracy: 0.9773 - lr: 5.5000e-04 - 134s/epoch - 119ms/step
# 0.9903360049072608
# 2
# 1122/1122 - 133s - loss: 0.0349 - accuracy: 0.9438 - val_loss: 0.0372 - val_accuracy: 0.9554 - lr: 3.0250e-04 - 133s/epoch - 119ms/step
# 0.9906583655104237
# 3
# 1122/1122 - 134s - loss: 0.0324 - accuracy: 0.9538 - val_loss: 0.0373 - val_accuracy: 0.9674 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9907720329471645
# 4
# 1122/1122 - 134s - loss: 0.0308 - accuracy: 0.9379 - val_loss: 0.0371 - val_accuracy: 0.9377 - lr: 9.1506e-05 - 134s/epoch - 120ms/step
# 0.9907581741048292
# 150/150 [==============================] - 39s 258ms/step
# 0
# 1122/1122 - 136s - loss: 0.0510 - accuracy: 0.9205 - val_loss: 0.0402 - val_accuracy: 0.9391 - lr: 0.0010 - 136s/epoch - 121ms/step
# 0.9899406381982172
# 1
# 1122/1122 - 133s - loss: 0.0385 - accuracy: 0.9690 - val_loss: 0.0380 - val_accuracy: 0.9807 - lr: 5.5000e-04 - 133s/epoch - 119ms/step
# 0.9905236206048081
# 2
# 1122/1122 - 133s - loss: 0.0350 - accuracy: 0.9715 - val_loss: 0.0378 - val_accuracy: 0.9690 - lr: 3.0250e-04 - 133s/epoch - 119ms/step
# 0.9909679619014861
# 3
# 1122/1122 - 134s - loss: 0.0326 - accuracy: 0.9701 - val_loss: 0.0371 - val_accuracy: 0.9761 - lr: 1.6638e-04 - 134s/epoch - 119ms/step
# 0.9909350424007569
# 4
# 1122/1122 - 133s - loss: 0.0309 - accuracy: 0.9694 - val_loss: 0.0372 - val_accuracy: 0.9303 - lr: 9.1506e-05 - 133s/epoch - 119ms/step
# 0.9910291728238457
# 150/150 [==============================] - 39s 260ms/step

# %% [markdown]
# # 4. Load Model

# %%
pred = 0

model = build_model(embedding_matrix)

for i in range(10):
  model.load_weights(MODEL_DIR + f'bilstm_gru_dual_embedding_{i}.h5')
  pred += model.predict(x_test, batch_size=1024, verbose=1)/10
# Out:
# 150/150 [==============================] - 23s 149ms/step
# 150/150 [==============================] - 22s 150ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step
# 150/150 [==============================] - 22s 149ms/step

# %%
submission[list_classes] = (pred)
submission
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  0.997470      0.403298  0.974170  0.169461
# 1       0000247867823ef7  0.000269      0.000010  0.000072  0.000004
# 2       00013b17ad220c46  0.000483      0.000089  0.000262  0.000053
# 3       00017563c3f7919a  0.000097      0.000003  0.000038  0.000018
# 4       00017695ad8997eb  0.004352      0.000095  0.000424  0.000040
# ...                  ...       ...           ...       ...       ...
# 153159  fffcd0960ee309b5  0.673565      0.000582  0.278641  0.000039
# 153160  fffd7a9a6eb32c16  0.006050      0.000073  0.000364  0.000878
# 153161  fffda9e8d6fafa9e  0.000330      0.000005  0.000132  0.000002
# 153162  fffe8f1340a79fc2  0.000896      0.000017  0.000079  0.000030
# 153163  ffffce3fb183ee80  0.988269      0.006953  0.853489  0.000787
#
#           insult  identity_hate
# 0       0.928706       0.481467
# 1       0.000054       0.000007
# 2       0.000190       0.000073
# 3       0.000038       0.000002
# 4       0.000250       0.000020
# ...          ...            ...
# 153159  0.054910       0.000608
# 153160  0.001206       0.000105
# 153161  0.000051       0.000014
# 153162  0.000116       0.001346
# 153163  0.401106       0.001354
#
# [153164 rows x 7 columns]

# %%
submission.to_csv(OUTPUT_DIR + "bi_lstm_gru_dual_embedding.csv", index = False)

# %%
# !kaggle competitions submit -c jigsaw-toxic-comment-classification-challenge -f /content/drive/MyDrive/NLP/ENG/Jigsaw1/output/bi_lstm_gru_dual_embedding.csv -m "bi_lstm_gru_dual_embedding"
# Out:
# 100% 13.8M/13.8M [00:01<00:00, 9.49MB/s]
# Successfully submitted to Toxic Comment Classification Challenge

# %%
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle//
# !cp kaggle.json ~/.kaggle/
# Permission Warning이 발생하지 않도록 해줍니다.
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-57949376-77f1-4a51-8f6c-3062523a0bef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57949376-77f1-4a51-8f6c-3062523a0bef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
